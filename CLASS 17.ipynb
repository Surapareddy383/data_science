# %%
import pandas as pd
import numpy as np

# %%
pd.date_range('2000-01-01','2020-02-09',freq='y')
# Out:
# DatetimeIndex(['2000-12-31', '2001-12-31', '2002-12-31', '2003-12-31',
#                '2004-12-31', '2005-12-31', '2006-12-31', '2007-12-31',
#                '2008-12-31', '2009-12-31', '2010-12-31', '2011-12-31',
#                '2012-12-31', '2013-12-31', '2014-12-31', '2015-12-31',
#                '2016-12-31', '2017-12-31', '2018-12-31', '2019-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.date_range('2000-01-01','2020-02-09',freq='m')
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31',
#                '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30',
#                '2019-12-31', '2020-01-31'],
#               dtype='datetime64[ns]', length=241, freq='M')

# %%
pd.date_range('2000-01-01','2020-02-09',freq='d')
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2020-01-31', '2020-02-01', '2020-02-02', '2020-02-03',
#                '2020-02-04', '2020-02-05', '2020-02-06', '2020-02-07',
#                '2020-02-08', '2020-02-09'],
#               dtype='datetime64[ns]', length=7345, freq='D')

# %%
pd.date_range('2000-01-01','2020-02-09',freq='h')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:00:00',
#                '2000-01-01 02:00:00', '2000-01-01 03:00:00',
#                '2000-01-01 04:00:00', '2000-01-01 05:00:00',
#                '2000-01-01 06:00:00', '2000-01-01 07:00:00',
#                '2000-01-01 08:00:00', '2000-01-01 09:00:00',
#                ...
#                '2020-02-08 15:00:00', '2020-02-08 16:00:00',
#                '2020-02-08 17:00:00', '2020-02-08 18:00:00',
#                '2020-02-08 19:00:00', '2020-02-08 20:00:00',
#                '2020-02-08 21:00:00', '2020-02-08 22:00:00',
#                '2020-02-08 23:00:00', '2020-02-09 00:00:00'],
#               dtype='datetime64[ns]', length=176257, freq='H')

# %%
pd.date_range('2000-01-01','2020-02-09',freq='T')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 00:01:00',
#                '2000-01-01 00:02:00', '2000-01-01 00:03:00',
#                '2000-01-01 00:04:00', '2000-01-01 00:05:00',
#                '2000-01-01 00:06:00', '2000-01-01 00:07:00',
#                '2000-01-01 00:08:00', '2000-01-01 00:09:00',
#                ...
#                '2020-02-08 23:51:00', '2020-02-08 23:52:00',
#                '2020-02-08 23:53:00', '2020-02-08 23:54:00',
#                '2020-02-08 23:55:00', '2020-02-08 23:56:00',
#                '2020-02-08 23:57:00', '2020-02-08 23:58:00',
#                '2020-02-08 23:59:00', '2020-02-09 00:00:00'],
#               dtype='datetime64[ns]', length=10575361, freq='T')

# %%
pd.date_range('2000-01-01','2020-02-09',freq='s')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 00:00:01',
#                '2000-01-01 00:00:02', '2000-01-01 00:00:03',
#                '2000-01-01 00:00:04', '2000-01-01 00:00:05',
#                '2000-01-01 00:00:06', '2000-01-01 00:00:07',
#                '2000-01-01 00:00:08', '2000-01-01 00:00:09',
#                ...
#                '2020-02-08 23:59:51', '2020-02-08 23:59:52',
#                '2020-02-08 23:59:53', '2020-02-08 23:59:54',
#                '2020-02-08 23:59:55', '2020-02-08 23:59:56',
#                '2020-02-08 23:59:57', '2020-02-08 23:59:58',
#                '2020-02-08 23:59:59', '2020-02-09 00:00:00'],
#               dtype='datetime64[ns]', length=634521601, freq='S')

# %%
dates=pd.date_range('2019-01-01',periods=100,freq='w-wed')
dates
# Out:
# DatetimeIndex(['2019-01-02', '2019-01-09', '2019-01-16', '2019-01-23',
#                '2019-01-30', '2019-02-06', '2019-02-13', '2019-02-20',
#                '2019-02-27', '2019-03-06', '2019-03-13', '2019-03-20',
#                '2019-03-27', '2019-04-03', '2019-04-10', '2019-04-17',
#                '2019-04-24', '2019-05-01', '2019-05-08', '2019-05-15',
#                '2019-05-22', '2019-05-29', '2019-06-05', '2019-06-12',
#                '2019-06-19', '2019-06-26', '2019-07-03', '2019-07-10',
#                '2019-07-17', '2019-07-24', '2019-07-31', '2019-08-07',
#                '2019-08-14', '2019-08-21', '2019-08-28', '2019-09-04',
#                '2019-09-11', '2019-09-18', '2019-09-25', '2019-10-02',
#                '2019-10-09', '2019-10-16', '2019-10-23', '2019-10-30',
#                '2019-11-06', '2019-11-13', '2019-11-20', '2019-11-27',
#                '2019-12-04', '2019-12-11', '2019-12-18', '2019-12-25',
# ...

# %%
t=pd.DataFrame(np.random.randn(100,4),index=dates,columns=['guntur','vijayawada','nellore','kurnool'])
t
# Out:
#               guntur  vijayawada   nellore   kurnool
# 2019-01-02 -0.792482    0.587860 -1.200616 -0.076836
# 2019-01-09 -2.594770   -1.343399 -0.765141  0.405728
# 2019-01-16 -0.228984    0.422641  0.480342 -0.297816
# 2019-01-23 -1.158068   -0.099715  1.046154  0.766419
# 2019-01-30  1.438114    0.548957 -0.582220 -0.723312
# 2019-02-06  0.852902   -0.349815 -0.762190  0.979408
# 2019-02-13 -0.171919    0.625387 -0.217109  0.111048
# 2019-02-20 -0.134213   -0.721056  0.675585 -1.341644
# 2019-02-27 -1.050729   -0.112317 -0.474163 -0.350885
# 2019-03-06  0.972666   -0.852389 -0.054821 -0.219011
# 2019-03-13 -0.549149    0.222266  1.883482 -0.682471
# 2019-03-20  1.078402    1.394313 -1.893317 -0.582416
# 2019-03-27 -0.226178   -0.014295  1.789185  0.299058
# 2019-04-03  0.231498   -1.679139  0.424234 -0.338494
# 2019-04-10 -0.132545    1.123990  1.634087  1.435554
# 2019-04-17  0.894111    0.112002 -0.540070  1.539525
# 2019-04-24  0.634089   -0.673678  0.024313 -0.275760
# ...

# %%
t.loc['2019/05/01']
# Out:
# guntur       -0.215425
# vijayawada    0.147678
# nellore      -1.041590
# kurnool      -1.667651
# Name: 2019-05-01 00:00:00, dtype: float64

# %%
REQ=input()
if REQ=='G':
    print("C")
elif REQ=='C':
    print("G")
elif REQ=='T':
    print("A")
elif REQ=='A':
    print("U")
else:
    print("Invalid Input")
# Out:
# ACGTGGTCTTAA
# Invalid Input

# %%
n=(input())
m=n.split()
m.sort(reverse=True)
print(m)
print(m[0])
# Out:
# 3659 3152 914
# ['914', '3659', '3152']
# 914
